# %% [markdown]
# # Website Scraping
# This is a simple program to scrap carpark information from a website using Pandas and BeautifulSoup and return it in csv.

# %%
import collections
import pandas as pd
import requests
from bs4 import BeautifulSoup
from datetime import datetime

# %% [markdown]
# ### Set up variables

# %%
# Set up dictionary
keys = ['Carpark Name', 'Carpark Address', 'Mon-Fri before 5/6pm', 'Mon-Fri after 5/6pm', 'Sat', 'Sun/Public Holiday']
d = collections.OrderedDict((key,[]) for key in keys)

# Set up variables
full_table = 0
location = 'na'
address = 'na'
url = 'na'

# %% [markdown]
# ### Define functions: web scraping, saving to dataframe, saving to csv

# %%
"""
This function takes the url and returns the parking fees of the carpark
"""
    
def readurl(url):
    dfs = pd.read_html(url)
    data = dfs[6] # dataframe 6 contains the required info
    global full_table
    full_table = data.iloc[:,0] # required info is in first column
    return full_table


"""
This function takes the url and returns the location and address of the carpark
"""

def add_and_loc(url):
    resp = requests.get(url)
    html_doc = resp.text
    soup = BeautifulSoup(html_doc, 'html.parser')

    title = soup.find(class_="grayboxborder") # this class contains the table of information
    global location
    location = title.text.strip()
    loc = location.split("\n")
    location = loc[0]
    global address
    address = loc[1].rstrip()
    return location, address


"""
This function appends all the information to the dictionary
"""

def append(full_table, location, address):
    global d
    d['Carpark Name'].append(location)
    d['Carpark Address'].append(address)
    d['Mon-Fri before 5/6pm'].append(full_table[1].replace('$','\$'))
    d['Mon-Fri after 5/6pm'].append(full_table[3].replace('$','\$'))
    d['Sat'].append(full_table[5].replace('$','\$'))
    d['Sun/Public Holiday'].append(full_table[7].replace('$','\$'))
    

"""
This function passes the dictionary into a dataframe and saves it into a csv file with today's date
"""

def convert(dictionary, n):
    df = pd.DataFrame.from_dict(dictionary, orient='index')
    dft = df.transpose()
    datestring = datetime.strftime(datetime.now(), '%Y%m%d')
    dft.to_csv('Parking_'+datestring+'_'+str(n)+'.csv', index=False)

# %% [markdown]
# ### Run functions

# %%
for n in range(0,10):
    for i in range( 1+(100*n) , 101+(100*n) ): # there are 926 webpages
        try:
            front_url = 'http://www.sgcarmart.com/news/carpark_index.php?ID='
            back_url = '&LOC=all&TYP=carpark&SRH=#carparkrates'
            url = front_url + str("%03d" % i) + back_url
            readurl(url)
            add_and_loc(url)
            append(full_table,location,address)
        except AttributeError: # skip blank/error pages and returns url for reference
            print(url + ' attr')
            i += 1
            continue
        except ValueError: # skip blank/error pages and returns url for reference
            print(url + ' val')
            i += 1
            continue
        except IndexError: # skip blank/error pages and returns url for reference
            print(url + ' index')
            i += 1
            continue

    convert(d,n) # creates a csv for every 100 in case of error midway
# Out:
# http://www.sgcarmart.com/news/carpark_index.php?ID=021&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=142&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=167&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=209&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=344&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=453&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=501&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=532&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=533&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=542&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=543&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=544&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=545&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=546&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=547&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=548&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=549&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=550&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=551&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=552&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=553&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=554&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=555&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=557&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=559&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=561&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=620&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=653&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=693&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=705&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=707&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=720&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=730&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=732&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=754&LOC=all&TYP=carpark&SRH=#carparkrates attr
# http://www.sgcarmart.com/news/carpark_index.php?ID=760&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=798&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=800&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=927&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=928&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=929&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=930&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=931&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=932&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=933&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=934&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=935&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=936&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=937&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=938&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=939&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=940&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=941&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=942&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=943&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=944&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=945&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=946&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=947&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=948&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=949&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=950&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=951&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=952&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=953&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=954&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=955&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=956&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=957&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=958&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=959&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=960&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=961&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=962&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=963&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=964&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=965&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=966&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=967&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=968&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=969&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=970&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=971&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=972&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=973&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=974&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=975&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=976&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=977&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=978&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=979&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=980&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=981&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=982&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=983&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=984&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=985&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=986&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=987&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=988&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=989&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=990&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=991&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=992&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=993&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=994&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=995&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=996&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=997&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=998&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=999&LOC=all&TYP=carpark&SRH=#carparkrates index
# http://www.sgcarmart.com/news/carpark_index.php?ID=1000&LOC=all&TYP=carpark&SRH=#carparkrates index
