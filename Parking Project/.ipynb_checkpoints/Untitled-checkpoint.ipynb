# %%
import pandas as pd

# %%
full_df = pd.read_csv('Parking_20171114_9.csv')
full_df.tail()
# Out:
#                               Carpark Name  \
# 884              Changi Airport Terminal 4
# 885                                  Wave9
# 886                Orchard Hotel Singapore
# 887                           Hillion Mall
# 888  NTFGH - Ng Teng Fong General Hospital
#
#                                 Carpark Address  \
# 884             10 Airport Boulevard, S(819665)
# 885  71 Woodlands Industrial Park E9, (S)757048
# 886                 442 Orchard Road, S(238879)
# 887                    17 Petir Road, S(678278)
# 888          1 Jurong East Street 21, S(609606)
#
#                                   Mon-Fri before 5/6pm  \
# 884  \$0.04/min from 12midnight to 12midnight the f...
# 885                          \$1.20/hr from 7am to 7pm
# 886  \$3.00 for 1st hr, \$1.50 for next subsequent ...
# 887  \$1.28 for 1st hr, \$0.43 for next subsequent ...
# 888                         \$0.03/min from 7am to 7pm
#
#                                    Mon-Fri after 5/6pm  \
# 884  Free Parking from 7pm to 12midnight, \$15/entr...
# 885     \$5.50/entry from 6pm to 7am the following day
# 886  \$2.57/entry from 6pm to 11pm, \$1.28 for 1st ...
# 887       \$0.03/min from 7pm to 7am the following day
# 888                                                NaN
#
#                                                    Sat  \
# 884  Free Parking from 7am to 12midnight, \$15/entr...
# 885                           Charges same as weekdays
# 886  \$2.57 for 1st 2hr, \$0.43 for next subsequent...
# 887                           Charges same as weekdays
# 888                                                NaN
#
#                                     Sun/Public Holiday
# 884  Free Parking from 7am to 12midnight, \$15/entr...
# 885     \$5.50/entry from 7am to 7am the following day
# 886  \$2.57 for 1st 2hr, \$0.43 for next subsequent...
# 887                           Charges same as weekdays
# 888                                                NaN

# %%
# Create new column ['Info']
full_df['Info'] = '<b>Carpark: </b>' + full_df['Carpark Name']
full_df['Info'] += '\n<b>Address: </b>' + full_df['Carpark Address']
full_df['Info'] += '\n<b>Mon-Fri before 5/6pm: </b>' + full_df['Mon-Fri before 5/6pm']
full_df['Info'] += '\n<b>Mon-Fri after 5/6pm: </b>' + full_df['Mon-Fri after 5/6pm']
full_df['Info'] += '\n<b>Sat: </b>' + full_df['Sat']
full_df['Info'] += '\n<b>Sun/ Public Holiday: </b>' + full_df['Sun/Public Holiday']

full_df.tail()
# Out:
#                               Carpark Name  \
# 884              Changi Airport Terminal 4
# 885                                  Wave9
# 886                Orchard Hotel Singapore
# 887                           Hillion Mall
# 888  NTFGH - Ng Teng Fong General Hospital
#
#                                 Carpark Address  \
# 884             10 Airport Boulevard, S(819665)
# 885  71 Woodlands Industrial Park E9, (S)757048
# 886                 442 Orchard Road, S(238879)
# 887                    17 Petir Road, S(678278)
# 888          1 Jurong East Street 21, S(609606)
#
#                                   Mon-Fri before 5/6pm  \
# 884  \$0.04/min from 12midnight to 12midnight the f...
# 885                          \$1.20/hr from 7am to 7pm
# 886  \$3.00 for 1st hr, \$1.50 for next subsequent ...
# 887  \$1.28 for 1st hr, \$0.43 for next subsequent ...
# 888                         \$0.03/min from 7am to 7pm
#
#                                    Mon-Fri after 5/6pm  \
# 884  Free Parking from 7pm to 12midnight, \$15/entr...
# 885     \$5.50/entry from 6pm to 7am the following day
# 886  \$2.57/entry from 6pm to 11pm, \$1.28 for 1st ...
# 887       \$0.03/min from 7pm to 7am the following day
# 888                                                NaN
#
#                                                    Sat  \
# 884  Free Parking from 7am to 12midnight, \$15/entr...
# 885                           Charges same as weekdays
# 886  \$2.57 for 1st 2hr, \$0.43 for next subsequent...
# 887                           Charges same as weekdays
# 888                                                NaN
#
#                                     Sun/Public Holiday  \
# 884  Free Parking from 7am to 12midnight, \$15/entr...
# 885     \$5.50/entry from 7am to 7am the following day
# 886  \$2.57 for 1st 2hr, \$0.43 for next subsequent...
# 887                           Charges same as weekdays
# 888                                                NaN
#
#                                                   Info
# 884  <b>Carpark: </b>Changi Airport Terminal 4\n<b>...
# 885  <b>Carpark: </b>Wave9\n<b>Address: </b>71 Wood...
# 886  <b>Carpark: </b>Orchard Hotel Singapore\n<b>Ad...
# 887  <b>Carpark: </b>Hillion Mall\n<b>Address: </b>...
# 888                                                NaN

# %%
searchfor = ['Carpark closed', 'Private Car Park', 'Carpark not in use', 'Season Parking Only','Building Demolished']
clean_df = full_df[~full_df['Mon-Fri before 5/6pm'].str.contains('|'.join(searchfor))]

clean_df.tail()
# Out:
#                               Carpark Name  \
# 884              Changi Airport Terminal 4
# 885                                  Wave9
# 886                Orchard Hotel Singapore
# 887                           Hillion Mall
# 888  NTFGH - Ng Teng Fong General Hospital
#
#                                 Carpark Address  \
# 884             10 Airport Boulevard, S(819665)
# 885  71 Woodlands Industrial Park E9, (S)757048
# 886                 442 Orchard Road, S(238879)
# 887                    17 Petir Road, S(678278)
# 888          1 Jurong East Street 21, S(609606)
#
#                                   Mon-Fri before 5/6pm  \
# 884  \$0.04/min from 12midnight to 12midnight the f...
# 885                          \$1.20/hr from 7am to 7pm
# 886  \$3.00 for 1st hr, \$1.50 for next subsequent ...
# 887  \$1.28 for 1st hr, \$0.43 for next subsequent ...
# 888                         \$0.03/min from 7am to 7pm
#
#                                    Mon-Fri after 5/6pm  \
# 884  Free Parking from 7pm to 12midnight, \$15/entr...
# 885     \$5.50/entry from 6pm to 7am the following day
# 886  \$2.57/entry from 6pm to 11pm, \$1.28 for 1st ...
# 887       \$0.03/min from 7pm to 7am the following day
# 888                                                NaN
#
#                                                    Sat  \
# 884  Free Parking from 7am to 12midnight, \$15/entr...
# 885                           Charges same as weekdays
# 886  \$2.57 for 1st 2hr, \$0.43 for next subsequent...
# 887                           Charges same as weekdays
# 888                                                NaN
#
#                                     Sun/Public Holiday  \
# 884  Free Parking from 7am to 12midnight, \$15/entr...
# 885     \$5.50/entry from 7am to 7am the following day
# 886  \$2.57 for 1st 2hr, \$0.43 for next subsequent...
# 887                           Charges same as weekdays
# 888                                                NaN
#
#                                                   Info
# 884  <b>Carpark: </b>Changi Airport Terminal 4\n<b>...
# 885  <b>Carpark: </b>Wave9\n<b>Address: </b>71 Wood...
# 886  <b>Carpark: </b>Orchard Hotel Singapore\n<b>Ad...
# 887  <b>Carpark: </b>Hillion Mall\n<b>Address: </b>...
# 888                                                NaN

# %%
# Create csv file
clean_df.to_csv('Parking.csv', index=False)

# %%
df = pd.read_csv('Parking.csv')
df.tail()
# Out:
#                               Carpark Name  \
# 828              Changi Airport Terminal 4
# 829                                  Wave9
# 830                Orchard Hotel Singapore
# 831                           Hillion Mall
# 832  NTFGH - Ng Teng Fong General Hospital
#
#                                 Carpark Address  \
# 828             10 Airport Boulevard, S(819665)
# 829  71 Woodlands Industrial Park E9, (S)757048
# 830                 442 Orchard Road, S(238879)
# 831                    17 Petir Road, S(678278)
# 832          1 Jurong East Street 21, S(609606)
#
#                                   Mon-Fri before 5/6pm  \
# 828  \$0.04/min from 12midnight to 12midnight the f...
# 829                          \$1.20/hr from 7am to 7pm
# 830  \$3.00 for 1st hr, \$1.50 for next subsequent ...
# 831  \$1.28 for 1st hr, \$0.43 for next subsequent ...
# 832                         \$0.03/min from 7am to 7pm
#
#                                    Mon-Fri after 5/6pm  \
# 828  Free Parking from 7pm to 12midnight, \$15/entr...
# 829     \$5.50/entry from 6pm to 7am the following day
# 830  \$2.57/entry from 6pm to 11pm, \$1.28 for 1st ...
# 831       \$0.03/min from 7pm to 7am the following day
# 832                                                NaN
#
#                                                    Sat  \
# 828  Free Parking from 7am to 12midnight, \$15/entr...
# 829                           Charges same as weekdays
# 830  \$2.57 for 1st 2hr, \$0.43 for next subsequent...
# 831                           Charges same as weekdays
# 832                                                NaN
#
#                                     Sun/Public Holiday  \
# 828  Free Parking from 7am to 12midnight, \$15/entr...
# 829     \$5.50/entry from 7am to 7am the following day
# 830  \$2.57 for 1st 2hr, \$0.43 for next subsequent...
# 831                           Charges same as weekdays
# 832                                                NaN
#
#                                                   Info
# 828  <b>Carpark: </b>Changi Airport Terminal 4\n<b>...
# 829  <b>Carpark: </b>Wave9\n<b>Address: </b>71 Wood...
# 830  <b>Carpark: </b>Orchard Hotel Singapore\n<b>Ad...
# 831  <b>Carpark: </b>Hillion Mall\n<b>Address: </b>...
# 832                                                NaN

# %%
df_coo = pd.read_csv('Parking_withcoords.csv')
df_coo.tail()
# Out:
#                               Carpark Name  \
# 828              Changi Airport Terminal 4
# 829                                  Wave9
# 830                Orchard Hotel Singapore
# 831                           Hillion Mall
# 832  NTFGH - Ng Teng Fong General Hospital
#
#                                 Carpark Address  \
# 828             10 Airport Boulevard, S(819665)
# 829  71 Woodlands Industrial Park E9, (S)757048
# 830                 442 Orchard Road, S(238879)
# 831                    17 Petir Road, S(678278)
# 832          1 Jurong East Street 21, S(609606)
#
#                                   Mon-Fri before 5/6pm  \
# 828  \$0.04/min from 12midnight to 12midnight the f...
# 829                          \$1.20/hr from 7am to 7pm
# 830  \$3.00 for 1st hr, \$1.50 for next subsequent ...
# 831  \$1.28 for 1st hr, \$0.43 for next subsequent ...
# 832                         \$0.03/min from 7am to 7pm
#
#                                    Mon-Fri after 5/6pm  \
# 828  Free Parking from 7pm to 12midnight, \$15/entr...
# 829     \$5.50/entry from 6pm to 7am the following day
# 830  \$2.57/entry from 6pm to 11pm, \$1.28 for 1st ...
# 831       \$0.03/min from 7pm to 7am the following day
# 832                                                NaN
#
#                                                    Sat  \
# 828  Free Parking from 7am to 12midnight, \$15/entr...
# 829                           Charges same as weekdays
# 830  \$2.57 for 1st 2hr, \$0.43 for next subsequent...
# 831                           Charges same as weekdays
# 832                                                NaN
#
#                                     Sun/Public Holiday  \
# 828  Free Parking from 7am to 12midnight, \$15/entr...
# 829     \$5.50/entry from 7am to 7am the following day
# 830  \$2.57 for 1st 2hr, \$0.43 for next subsequent...
# 831                           Charges same as weekdays
# 832                                                NaN
#
#                                                   Info  \
# 828  <b>Carpark: </b>Changi Airport Terminal 4\r<b>...
# 829  <b>Carpark: </b>Wave9\r<b>Address: </b>71 Wood...
# 830  <b>Carpark: </b>Orchard Hotel Singapore\r<b>Ad...
# 831  <b>Carpark: </b>Hillion Mall\r<b>Address: </b>...
# 832                                                NaN
#
#                                       Coord_rad
# 828   (0.023813624870719537, 1.814994606649093)
# 829  (0.025281628285888973, 1.8116059259879689)
# 830  (0.022822754330472549, 1.8121491719349569)
# 831  (0.024049249555726529, 1.8110140796026299)
# 832  (0.023279917148093687, 1.8106954732383369)

# %%
df_new = pd.merge(df, df_coo[['Carpark Name','Coord_rad']], on='Carpark Name')
df_new.tail()
# Out:
#                               Carpark Name  \
# 828              Changi Airport Terminal 4
# 829                                  Wave9
# 830                Orchard Hotel Singapore
# 831                           Hillion Mall
# 832  NTFGH - Ng Teng Fong General Hospital
#
#                                 Carpark Address  \
# 828             10 Airport Boulevard, S(819665)
# 829  71 Woodlands Industrial Park E9, (S)757048
# 830                 442 Orchard Road, S(238879)
# 831                    17 Petir Road, S(678278)
# 832          1 Jurong East Street 21, S(609606)
#
#                                   Mon-Fri before 5/6pm  \
# 828  \$0.04/min from 12midnight to 12midnight the f...
# 829                          \$1.20/hr from 7am to 7pm
# 830  \$3.00 for 1st hr, \$1.50 for next subsequent ...
# 831  \$1.28 for 1st hr, \$0.43 for next subsequent ...
# 832                         \$0.03/min from 7am to 7pm
#
#                                    Mon-Fri after 5/6pm  \
# 828  Free Parking from 7pm to 12midnight, \$15/entr...
# 829     \$5.50/entry from 6pm to 7am the following day
# 830  \$2.57/entry from 6pm to 11pm, \$1.28 for 1st ...
# 831       \$0.03/min from 7pm to 7am the following day
# 832                                                NaN
#
#                                                    Sat  \
# 828  Free Parking from 7am to 12midnight, \$15/entr...
# 829                           Charges same as weekdays
# 830  \$2.57 for 1st 2hr, \$0.43 for next subsequent...
# 831                           Charges same as weekdays
# 832                                                NaN
#
#                                     Sun/Public Holiday  \
# 828  Free Parking from 7am to 12midnight, \$15/entr...
# 829     \$5.50/entry from 7am to 7am the following day
# 830  \$2.57 for 1st 2hr, \$0.43 for next subsequent...
# 831                           Charges same as weekdays
# 832                                                NaN
#
#                                                   Info  \
# 828  <b>Carpark: </b>Changi Airport Terminal 4\n<b>...
# 829  <b>Carpark: </b>Wave9\n<b>Address: </b>71 Wood...
# 830  <b>Carpark: </b>Orchard Hotel Singapore\n<b>Ad...
# 831  <b>Carpark: </b>Hillion Mall\n<b>Address: </b>...
# 832                                                NaN
#
#                                       Coord_rad
# 828   (0.023813624870719537, 1.814994606649093)
# 829  (0.025281628285888973, 1.8116059259879689)
# 830  (0.022822754330472549, 1.8121491719349569)
# 831  (0.024049249555726529, 1.8110140796026299)
# 832  (0.023279917148093687, 1.8106954732383369)

# %%
df_new.to_csv('Parking_withcoords.csv', index=False)

# %%
csv = pd.read_csv('Parking_withcoords.csv')
csv.head()
# Out:
#                                         Carpark Name  \
# 0  Lee Kong Chian Reference Library (National Lib...
# 1                               National Skin Centre
# 2                 National University Hospital (NUH)
# 3                                       Negara Hotel
# 4                         Northpoint Shopping Centre
#
#                       Carpark Address  \
# 0      100 Victoria Street, S(188064)
# 1          1 Mandalay Road, S(308205)
# 2  5 Lower Kent Ridge Road, S(119074)
# 3         10 Claymore Road, S(229540)
# 4      930 Yishun Avenue 2, S(769098)
#
#                                 Mon-Fri before 5/6pm  \
# 0  \$1.07 for 1st 30min, \$0.035/min from 7am to 7pm
# 1  \$2.20 for 1st hr, \$0.10 for next subsequent ...
# 2  \$0.035/min from 12midnight to 12midnight the ...
# 3  \$5.00 for 1st hr, \$1.50 for next subsequent ...
# 4  \$1.20 for 1st hr, \$0.80 for next subsequent ...
#
#                                  Mon-Fri after 5/6pm  \
# 0                    \$0.017/min from 7pm to 11.30pm
# 1                                     Carpark closed
# 2  \$0.035/min from 12midnight to 12midnight the ...
# 3     \$5.00/entry from 5pm to 7am the following day
# 4  \$1.20 for 1st hr, \$0.80 for next subsequent ...
#
#                         Sat                              Sun/Public Holiday  \
# 0  Charges same as weekdays                 \$0.017/min from 7am to 11.30pm
# 1            Carpark closed                                  Carpark closed
# 2  Charges same as weekdays                        Charges same as weekdays
# 3  Charges same as weekdays  \$5.00/entry from 7am to 7am the following day
# 4  Charges same as weekdays                        Charges same as weekdays
#
#                                                 Info  \
# 0  <b>Carpark: </b>Lee Kong Chian Reference Libra...
# 1  <b>Carpark: </b>National Skin Centre\n<b>Addre...
# 2  <b>Carpark: </b>National University Hospital (...
# 3  <b>Carpark: </b>Negara Hotel\n<b>Address: </b>...
# 4  <b>Carpark: </b>Northpoint Shopping Centre\n<b...
#
#                                     Coord_rad
# 0  (0.022645877428087689, 1.8125931365727745)
# 1  (0.023039621962008358, 1.8125092560489238)
# 2  (0.022588244910857584, 1.8113508967323384)
# 3  (0.022822040490808482, 1.8121774707034488)
# 4   (0.024950970423110893, 1.812280768015228)
