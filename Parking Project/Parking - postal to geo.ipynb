# %%
import pandas as pd
from haversine import haversine
from math import radians

# %%
def postalcode(postal):
    front_url = "https://maps.googleapis.com/maps/api/geocode/json?address="
    end_url = "&components=country:SG&key=AIzaSyB-lR8VoOizlVvhK-p8CR6Lol-wb2RgSM0"
    postal = str(postal)

    url = front_url + postal + end_url
    address = pd.read_json(url)
    p_lat = radians(address['results'][0]['geometry']['location']['lat'])
    p_lng = radians(address['results'][0]['geometry']['location']['lng'])
    return (p_lat, p_lng)

text='548136'
postal = postalcode(int(text))

# %%
df = pd.read_csv('Parking_20170918_geo.csv')
carparks = df.copy()
carparks.head()
# Out:
#                                         Carpark Name  \
# 0  Lee Kong Chian Reference Library (National Lib...
# 1                               National Skin Centre
# 2                 National University Hospital (NUH)
# 3                                       Negara Hotel
# 4                         Northpoint Shopping Centre
#
#                       Carpark Address  \
# 0      100 Victoria Street, S(188064)
# 1          1 Mandalay Road, S(308205)
# 2  5 Lower Kent Ridge Road, S(119074)
# 3         10 Claymore Road, S(229540)
# 4      930 Yishun Avenue 2, S(769098)
#
#                                 Mon-Fri before 5/6pm  \
# 0  \$1.07 for 1st 30min, \$0.035 for next subsequ...
# 1  \$2.20 for 1st hr, \$0.10 for next subsequent ...
# 2  \$0.035/min from 12midnight to 12midnight the ...
# 3  \$5.00 for 1st hr, \$1.50 for next subsequent ...
# 4  \$1.20 for 1st hr, \$0.80 for next subsequent ...
#
#                                  Mon-Fri after 5/6pm  \
# 0                    \$0.017/min from 7pm to 11.29pm
# 1                                     Carpark closed
# 2  \$0.035/min from 12midnight to 12midnight the ...
# 3     \$5.00/entry from 5pm to 7am the following day
# 4  \$1.20 for 1st hr, \$0.80 for next subsequent ...
#
#                         Sat                              Sun/Public Holiday  \
# 0  Charges same as weekdays                 \$0.017/min from 7am to 11.29pm
# 1            Carpark closed                                  Carpark closed
# 2  Charges same as weekdays                        Charges same as weekdays
# 3  Charges same as weekdays  \$5.00/entry from 7am to 7am the following day
# 4  Charges same as weekdays                        Charges same as weekdays
#
#    Latitude   Longitude                                     Coord
# 0  1.297513  103.853937           (1.2975132, 103.85393670000001)
# 1  1.320073  103.849131         (1.3200731000000001, 103.8491307)
# 2  1.294211  103.782762  (1.2942111000000001, 103.78276159999999)
# 3  1.307607  103.830121         (1.3076066000000002, 103.8301208)
# 4  1.429585  103.836039         (1.4295853000000001, 103.8360393)

# %%
Latitude_rad = []
for lat in carparks['Latitude']:
    lat_rad = radians(lat)
    Latitude_rad.append(lat_rad)
carparks['Latitude_rad'] = Latitude_rad

Longitude_rad = []
for lng in carparks['Longitude']:
    lng_rad = radians(lng)
    Longitude_rad.append(lng_rad)
carparks['Longitude_rad'] = Longitude_rad

# %%
carparks['Coord_rad'] = list(zip(carparks.Latitude_rad, carparks.Longitude_rad))

# %%
distance = []
for coord in carparks['Coord_rad']:  
    carpark = haversine(postal, coord)
    distance.append(carpark)

# %%
carparks['Distance_km'] = distance
carparks.head()
# Out:
#                                         Carpark Name  \
# 0  Lee Kong Chian Reference Library (National Lib...
# 1                               National Skin Centre
# 2                 National University Hospital (NUH)
# 3                                       Negara Hotel
# 4                         Northpoint Shopping Centre
#
#                       Carpark Address  \
# 0      100 Victoria Street, S(188064)
# 1          1 Mandalay Road, S(308205)
# 2  5 Lower Kent Ridge Road, S(119074)
# 3         10 Claymore Road, S(229540)
# 4      930 Yishun Avenue 2, S(769098)
#
#                                 Mon-Fri before 5/6pm  \
# 0  \$1.07 for 1st 30min, \$0.035 for next subsequ...
# 1  \$2.20 for 1st hr, \$0.10 for next subsequent ...
# 2  \$0.035/min from 12midnight to 12midnight the ...
# 3  \$5.00 for 1st hr, \$1.50 for next subsequent ...
# 4  \$1.20 for 1st hr, \$0.80 for next subsequent ...
#
#                                  Mon-Fri after 5/6pm  \
# 0                    \$0.017/min from 7pm to 11.29pm
# 1                                     Carpark closed
# 2  \$0.035/min from 12midnight to 12midnight the ...
# 3     \$5.00/entry from 5pm to 7am the following day
# 4  \$1.20 for 1st hr, \$0.80 for next subsequent ...
#
#                         Sat                              Sun/Public Holiday  \
# 0  Charges same as weekdays                 \$0.017/min from 7am to 11.29pm
# 1            Carpark closed                                  Carpark closed
# 2  Charges same as weekdays                        Charges same as weekdays
# 3  Charges same as weekdays  \$5.00/entry from 7am to 7am the following day
# 4  Charges same as weekdays                        Charges same as weekdays
#
#    Latitude   Longitude                                     Coord  \
# 0  1.297513  103.853937           (1.2975132, 103.85393670000001)
# 1  1.320073  103.849131         (1.3200731000000001, 103.8491307)
# 2  1.294211  103.782762  (1.2942111000000001, 103.78276159999999)
# 3  1.307607  103.830121         (1.3076066000000002, 103.8301208)
# 4  1.429585  103.836039         (1.4295853000000001, 103.8360393)
#
#    Latitude_rad  Longitude_rad                         Coord_rad  Distance_km
# 0      0.022646       1.812593  (0.0226458774281, 1.81259313657)     0.127682
# 1      0.023040       1.812509   (0.023039621962, 1.81250925605)     0.095236
# 2      0.022588       1.811351  (0.0225882449109, 1.81135089673)     0.226506
# 3      0.022822       1.812177   (0.0228220404908, 1.8121774707)     0.138092
# 4      0.024951       1.812281  (0.0249509704231, 1.81228076802)     0.164507

# %%
top_five = carparks.sort_values('Distance_km').head(5)
top_five_condensed = top_five.iloc[:,:6]
top_five_condensed
# Out:
#                 Carpark Name                       Carpark Address  \
# 789          Highland Centre       22 Yio Chu Kang Road, S(545535)
# 625           Heartland Mall      205 Hougang Street 21, S(530205)
# 425             Kovan Centre        9 Yio Chu Kang Road, S(545523)
# 518        Serangoon Stadium       35 Yio Chu Kang Road, S(545552)
# 343  Da Jin Factory Building  362 Upper Paya Lebar Road, S(534963)
#
#                                   Mon-Fri before 5/6pm  \
# 789  \$0.27/15min from 8am to 1.59pm, \$0.27/10min ...
# 625                      \$1.00/hr from 7am to 10.30pm
# 425                              *Building Demolished*
# 518                            HDB / URA parking rates
# 343                       \$1.33/hr from 8am to 4.59pm
#
#                                    Mon-Fri after 5/6pm  \
# 789                   \$2.50/entry from 6pm to 11.59pm
# 625    \$2.00/hr from 10.30pm to 7am the following day
# 425                              *Building Demolished*
# 518                            HDB / URA parking rates
# 343  \$1.63/entry from 5pm to 10pm, Car Park closed...
#
#                           Sat        Sun/Public Holiday
# 789  Charges same as weekdays  Charges same as weekdays
# 625  Charges same as weekdays  Charges same as weekdays
# 425     *Building Demolished*     *Building Demolished*
# 518   HDB / URA parking rates   HDB / URA parking rates
# 343  Charges same as weekdays                    Closed

# %%
for row in top_five_condensed.iterrows():
    print(row)
# Out:
# (789, Carpark Name                                              Highland Centre
# Carpark Address                           22 Yio Chu Kang Road, S(545535)
# Mon-Fri before 5/6pm    \$0.27/15min from 8am to 1.59pm, \$0.27/10min ...
# Mon-Fri after 5/6pm                      \$2.50/entry from 6pm to 11.59pm
# Sat                                              Charges same as weekdays
# Sun/Public Holiday                               Charges same as weekdays
# Name: 789, dtype: object)
# (625, Carpark Name                                             Heartland Mall
# Carpark Address                        205 Hougang Street 21, S(530205)
# Mon-Fri before 5/6pm                      \$1.00/hr from 7am to 10.30pm
# Mon-Fri after 5/6pm     \$2.00/hr from 10.30pm to 7am the following day
# Sat                                            Charges same as weekdays
# Sun/Public Holiday                             Charges same as weekdays
# Name: 625, dtype: object)
# (425, Carpark Name                              Kovan Centre
# Carpark Address         9 Yio Chu Kang Road, S(545523)
# Mon-Fri before 5/6pm             *Building Demolished*
# Mon-Fri after 5/6pm              *Building Demolished*
# Sat                              *Building Demolished*
# Sun/Public Holiday               *Building Demolished*
# Name: 425, dtype: object)
# (518, Carpark Name                          Serangoon Stadium
# Carpark Address         35 Yio Chu Kang Road, S(545552)
# Mon-Fri before 5/6pm            HDB / URA parking rates
# Mon-Fri after 5/6pm             HDB / URA parking rates
# Sat                             HDB / URA parking rates
# Sun/Public Holiday              HDB / URA parking rates
# Name: 518, dtype: object)
# (343, Carpark Name                                      Da Jin Factory Building
# Carpark Address                      362 Upper Paya Lebar Road, S(534963)
# Mon-Fri before 5/6pm                         \$1.33/hr from 8am to 4.59pm
# Mon-Fri after 5/6pm     \$1.63/entry from 5pm to 10pm, Car Park closed...
# Sat                                              Charges same as weekdays
# Sun/Public Holiday                                                 Closed
# Name: 343, dtype: object)
