# %%
import pandas as pd
df = pd.read_csv('Parking_20170918_geo.csv')
df.rename({'Longtitude':'Longitude'})
df
# Out:
#                                           Carpark Name  \
# 0    Lee Kong Chian Reference Library (National Lib...
# 1                                 National Skin Centre
# 2                   National University Hospital (NUH)
# 3                                         Negara Hotel
# 4                           Northpoint Shopping Centre
# 5                                       Novena Gardens
# 6                             Velocity @ Novena Square
# 7                                         Novena Villa
# 8             National Cancer Centre, Singapore (NCCS)
# 9                                              M Hotel
# 10                               Marina Mandarin Hotel
# 11                                       Marina Square
# 12                                     Manulife Centre
# 13                                     Peninsula Plaza
# 14                                People's Park Centre
# 15                                         OCBC Centre
# ...
